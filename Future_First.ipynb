# %% [markdown]
# <a href="https://colab.research.google.com/github/prav87654/German-10-year-bund-Futures/blob/main/Future_First.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing modules
import numpy as np 
import pandas as pd 

import warnings
warnings.filterwarnings('ignore')

# %%
#importing dataset
stock_df=pd.read_csv('/content/drive/MyDrive/German 10 YR Bund Futures Historical Data (1).csv')

# %%
stock_df
# Out:
#               Date   Price    Open    High     Low     Vol. Change %
# 0     Jun 15, 2022  144.61  142.73  145.51  142.25    1.29M    0.71%
# 1     Jun 14, 2022  143.59  144.65  145.58  142.29    1.26M   -1.10%
# 2     Jun 13, 2022  145.18  146.71  147.19  144.19    1.10M   -1.22%
# 3     Jun 10, 2022  146.98  147.74  148.51  146.61  956.29K   -0.55%
# 4     Jun 09, 2022  147.80  148.69  149.43  147.32    1.04M   -0.79%
# ...            ...     ...     ...     ...     ...      ...      ...
# 1134  Jan 08, 2018  161.80  161.64  162.04  161.39  454.69K    0.13%
# 1135  Jan 05, 2018  161.59  161.70  161.87  161.50  467.09K    0.00%
# 1136  Jan 04, 2018  161.59  161.44  161.75  161.26  640.61K    0.01%
# 1137  Jan 03, 2018  161.58  161.26  161.82  161.20  604.24K    0.19%
# 1138  Jan 02, 2018  161.28  161.78  161.78  161.18  485.60K   -0.25%
#
# [1139 rows x 7 columns]

# %%
#First five rows of the dataset
stock_df.head(5)
# Out:
#            Date   Price    Open    High     Low     Vol. Change %
# 0  Jun 15, 2022  144.61  142.73  145.51  142.25    1.29M    0.71%
# 1  Jun 14, 2022  143.59  144.65  145.58  142.29    1.26M   -1.10%
# 2  Jun 13, 2022  145.18  146.71  147.19  144.19    1.10M   -1.22%
# 3  Jun 10, 2022  146.98  147.74  148.51  146.61  956.29K   -0.55%
# 4  Jun 09, 2022  147.80  148.69  149.43  147.32    1.04M   -0.79%

# %%
#Last Five rows of the dataset
stock_df.tail(5)
# Out:
#               Date   Price    Open    High     Low     Vol. Change %
# 1134  Jan 08, 2018  161.80  161.64  162.04  161.39  454.69K    0.13%
# 1135  Jan 05, 2018  161.59  161.70  161.87  161.50  467.09K    0.00%
# 1136  Jan 04, 2018  161.59  161.44  161.75  161.26  640.61K    0.01%
# 1137  Jan 03, 2018  161.58  161.26  161.82  161.20  604.24K    0.19%
# 1138  Jan 02, 2018  161.28  161.78  161.78  161.18  485.60K   -0.25%

# %%
#Checking for null values
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1139 entries, 0 to 1138
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1139 non-null   object
#  1   Price     1139 non-null   float64
#  2   Open      1139 non-null   float64
#  3   High      1139 non-null   float64
#  4   Low       1139 non-null   float64
#  5   Vol.      1139 non-null   object
#  6   Change %  1139 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 62.4+ KB

# %%
#Statistical details of the dataset
stock_df.describe(include='all')
# Out:
#                 Date        Price         Open         High          Low  \
# count           1139  1139.000000  1139.000000  1139.000000  1139.000000
# unique          1139          NaN          NaN          NaN          NaN
# top     Jun 15, 2022          NaN          NaN          NaN          NaN
# freq               1          NaN          NaN          NaN          NaN
# mean             NaN   168.579350   168.583205   168.954170   168.196365
# std              NaN     6.983063     6.962133     6.940679     6.999907
# min              NaN   143.590000   142.730000   145.510000   142.250000
# 25%              NaN   162.710000   162.675000   163.045000   162.430000
# 50%              NaN   170.750000   170.750000   171.150000   170.310000
# 75%              NaN   174.270000   174.250000   174.630000   173.900000
# max              NaN   179.440000   179.390000   179.670000   179.000000
#
#          Vol. Change %
# count    1139     1139
# unique   1071      178
# ...

# %%
#Removing the price column
column=stock_df.pop("Price")
column
# Out:
# 0       144.61
# 1       143.59
# 2       145.18
# 3       146.98
# 4       147.80
#          ...
# 1134    161.80
# 1135    161.59
# 1136    161.59
# 1137    161.58
# 1138    161.28
# Name: Price, Length: 1139, dtype: float64

# %%
#Adding the price column at the 5th postion and renaming it as Close
stock_df.insert(4,'Close',column)
stock_df
# Out:
#               Date    Open    High     Low   Close     Vol. Change %
# 0     Jun 15, 2022  142.73  145.51  142.25  144.61    1.29M    0.71%
# 1     Jun 14, 2022  144.65  145.58  142.29  143.59    1.26M   -1.10%
# 2     Jun 13, 2022  146.71  147.19  144.19  145.18    1.10M   -1.22%
# 3     Jun 10, 2022  147.74  148.51  146.61  146.98  956.29K   -0.55%
# 4     Jun 09, 2022  148.69  149.43  147.32  147.80    1.04M   -0.79%
# ...            ...     ...     ...     ...     ...      ...      ...
# 1134  Jan 08, 2018  161.64  162.04  161.39  161.80  454.69K    0.13%
# 1135  Jan 05, 2018  161.70  161.87  161.50  161.59  467.09K    0.00%
# 1136  Jan 04, 2018  161.44  161.75  161.26  161.59  640.61K    0.01%
# 1137  Jan 03, 2018  161.26  161.82  161.20  161.58  604.24K    0.19%
# 1138  Jan 02, 2018  161.78  161.78  161.18  161.28  485.60K   -0.25%
#
# [1139 rows x 7 columns]

# %%
#Changing the datatype of Date from object to Datetime
stock_df['Date']=pd.to_datetime(stock_df['Date'])
stock_df
# Out:
#            Date    Open    High     Low   Close     Vol. Change %
# 0    2022-06-15  142.73  145.51  142.25  144.61    1.29M    0.71%
# 1    2022-06-14  144.65  145.58  142.29  143.59    1.26M   -1.10%
# 2    2022-06-13  146.71  147.19  144.19  145.18    1.10M   -1.22%
# 3    2022-06-10  147.74  148.51  146.61  146.98  956.29K   -0.55%
# 4    2022-06-09  148.69  149.43  147.32  147.80    1.04M   -0.79%
# ...         ...     ...     ...     ...     ...      ...      ...
# 1134 2018-01-08  161.64  162.04  161.39  161.80  454.69K    0.13%
# 1135 2018-01-05  161.70  161.87  161.50  161.59  467.09K    0.00%
# 1136 2018-01-04  161.44  161.75  161.26  161.59  640.61K    0.01%
# 1137 2018-01-03  161.26  161.82  161.20  161.58  604.24K    0.19%
# 1138 2018-01-02  161.78  161.78  161.18  161.28  485.60K   -0.25%
#
# [1139 rows x 7 columns]

# %%
#Setting the Date as Index
stock_df = stock_df.set_index(pd.DatetimeIndex(stock_df['Date'].values))

# %%
#Sorting the dataset in the  ascending order of Date
stock_df.sort_values(by='Date', inplace = True) 
stock_df
# Out:
#                  Date    Open    High     Low   Close     Vol. Change %
# 2018-01-02 2018-01-02  161.78  161.78  161.18  161.28  485.60K   -0.25%
# 2018-01-03 2018-01-03  161.26  161.82  161.20  161.58  604.24K    0.19%
# 2018-01-04 2018-01-04  161.44  161.75  161.26  161.59  640.61K    0.01%
# 2018-01-05 2018-01-05  161.70  161.87  161.50  161.59  467.09K    0.00%
# 2018-01-08 2018-01-08  161.64  162.04  161.39  161.80  454.69K    0.13%
# ...               ...     ...     ...     ...     ...      ...      ...
# 2022-06-09 2022-06-09  148.69  149.43  147.32  147.80    1.04M   -0.79%
# 2022-06-10 2022-06-10  147.74  148.51  146.61  146.98  956.29K   -0.55%
# 2022-06-13 2022-06-13  146.71  147.19  144.19  145.18    1.10M   -1.22%
# 2022-06-14 2022-06-14  144.65  145.58  142.29  143.59    1.26M   -1.10%
# 2022-06-15 2022-06-15  142.73  145.51  142.25  144.61    1.29M    0.71%
#
# [1139 rows x 7 columns]

# %%
#Calculating the True range 
high_low = stock_df['High'] - stock_df['Low']
high_cp = np.abs(stock_df['High'] - stock_df['Close'].shift())
low_cp = np.abs(stock_df['Low'] - stock_df['Close'].shift())

# %%
#Concating the True range values to calculate the ATR
df=pd.concat([high_low,high_cp,low_cp],axis=1)
true_range = np.max(df, axis=1)
true_range
# Out:
# 2018-01-02    0.60
# 2018-01-03    0.62
# 2018-01-04    0.49
# 2018-01-05    0.37
# 2018-01-08    0.65
#               ...
# 2022-06-09    2.11
# 2022-06-10    1.90
# 2022-06-13    3.00
# 2022-06-14    3.29
# 2022-06-15    3.26
# Length: 1139, dtype: float64

# %%
# Getting the ATR value on the rolling of 14
avg_true_range = true_range.rolling(14).mean()
avg_true_range
# Out:
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
# 2018-01-08         NaN
#                 ...
# 2022-06-09    1.187857
# 2022-06-10    1.233571
# 2022-06-13    1.361429
# 2022-06-14    1.528571
# 2022-06-15    1.650714
# Length: 1139, dtype: float64

# %%
#Adding the ATR column in the dataset
stock_df['atr'] = avg_true_range
stock_df
# Out:
#                  Date    Open    High     Low   Close     Vol. Change %  \
# 2018-01-02 2018-01-02  161.78  161.78  161.18  161.28  485.60K   -0.25%
# 2018-01-03 2018-01-03  161.26  161.82  161.20  161.58  604.24K    0.19%
# 2018-01-04 2018-01-04  161.44  161.75  161.26  161.59  640.61K    0.01%
# 2018-01-05 2018-01-05  161.70  161.87  161.50  161.59  467.09K    0.00%
# 2018-01-08 2018-01-08  161.64  162.04  161.39  161.80  454.69K    0.13%
# ...               ...     ...     ...     ...     ...      ...      ...
# 2022-06-09 2022-06-09  148.69  149.43  147.32  147.80    1.04M   -0.79%
# 2022-06-10 2022-06-10  147.74  148.51  146.61  146.98  956.29K   -0.55%
# 2022-06-13 2022-06-13  146.71  147.19  144.19  145.18    1.10M   -1.22%
# 2022-06-14 2022-06-14  144.65  145.58  142.29  143.59    1.26M   -1.10%
# 2022-06-15 2022-06-15  142.73  145.51  142.25  144.61    1.29M    0.71%
#
#                  atr
# 2018-01-02       NaN
# 2018-01-03       NaN
# 2018-01-04       NaN
# ...

# %%
#define the window for moving standard deviation
window = input("Enter the window size for moving standard deviation: ")
# Out:
# Enter the window size for moving standard deviation: 5

# %%
#calculate the moving standard deviation
stock_df['Std_Dev_Close'] = stock_df['Close'].rolling(window=int(window)).std()
stock_df['Std_Dev_ATR'] = stock_df['atr'].rolling(window=int(window)).std()
stock_df.head(20)
# Out:
#                  Date    Open    High     Low   Close     Vol. Change %  \
# 2018-01-02 2018-01-02  161.78  161.78  161.18  161.28  485.60K   -0.25%
# 2018-01-03 2018-01-03  161.26  161.82  161.20  161.58  604.24K    0.19%
# 2018-01-04 2018-01-04  161.44  161.75  161.26  161.59  640.61K    0.01%
# 2018-01-05 2018-01-05  161.70  161.87  161.50  161.59  467.09K    0.00%
# 2018-01-08 2018-01-08  161.64  162.04  161.39  161.80  454.69K    0.13%
# 2018-01-09 2018-01-09  161.67  162.00  161.20  161.30  719.57K   -0.31%
# 2018-01-10 2018-01-10  161.00  161.37  160.91  161.07  870.62K   -0.14%
# 2018-01-11 2018-01-11  161.38  161.55  160.27  160.31    1.06M   -0.47%
# 2018-01-12 2018-01-12  160.42  160.65  160.11  160.38  781.17K    0.04%
# 2018-01-15 2018-01-15  160.59  160.76  160.30  160.34  328.10K   -0.02%
# 2018-01-16 2018-01-16  160.46  160.97  160.41  160.77  632.57K    0.27%
# 2018-01-17 2018-01-17  160.78  160.97  160.65  160.82  514.18K    0.03%
# ...

# %%
#Importing the plotly for visualization
import plotly.graph_objects as go

# %%
fig= go.Figure(
    data = [
            go.Candlestick(
                x = stock_df.index,
                low = stock_df['Low'],
                high = stock_df['High'],
                close = stock_df['Close'],
                open = stock_df['Open'],
                increasing_line_color = 'red',
                decreasing_line_color = 'black',
                name = 'Daily Price'              
            )
    ]
)

# Add the ATR chart on a different vertical axis
fig.add_trace(go.Scatter(x=stock_df.index, y=stock_df['atr'], name="ATR", yaxis='y2'))

# Add input box for windowsize
fig.update_layout(
    updatemenus=[
        go.layout.Updatemenu(
            type='dropdown',
            buttons=list([
                dict(
                    args=[{"y": [stock_df['Close'],stock_df['atr'].rolling(window=i).std()]}],
                    label=str(i),
                    method='update'
                ) for i in [0,10,20,30,50,100,200,250]
            ]),
            direction = "down",
            pad = {"r": 10, "t": 10},
            showactive = True,
            x = 0.1,
            xanchor = "left",
            y = 1.1,
            yanchor = "top"
        ),
    ])


# Adding the moving standard deviation on an chart
fig.add_trace(go.Scatter(x=stock_df.index, y=stock_df['Std_Dev_Close'], name="Standard Deviation Close", yaxis='y3'))
fig.add_trace(go.Scatter(x=stock_df.index, y=stock_df['Std_Dev_ATR'], name="Standard Deviation ATR", yaxis='y4'))

fig.update_layout(
    title = 'German 10 Year Bund Futures ',
    yaxis_title = 'Euros(€)',
    yaxis2=dict(title='ATR', overlaying='y', side='right'),
    yaxis3=dict(overlaying='y', side='left'),
    yaxis4=dict(overlaying='y', side='left'),
    xaxis_title = 'Date Range'    
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
